# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
columns_names = []

# %%
df = pd.read_csv("sdreDataset.csv", names=range(1, 10))

# %%
cur_traj = df.values[0:101]

# %%
plt.figure(figsize=(20, 2.5))

for i in range(1, 10):
    plt.subplot(1, 9, i)
    plt.plot(cur_traj[:, i-1])
    plt.title(i)

# %% [markdown]
# ### 7, 8, 9 -- управление

# %%
df
# Out:
#                   1             2             3             4         5  \
# 0      6.294474e-01  8.115839e-01 -7.460264e-01  7.124575e-02 -0.069132
# 1      4.701187e-01  6.155137e-01 -5.583394e-01  3.168184e-01  0.315895
# 2      3.442394e-01  4.618880e-01 -4.151322e-01  4.404227e-01  0.549854
# 3      2.498603e-01  3.464365e-01 -3.105318e-01  4.835861e-01  0.667733
# 4      1.795987e-01  2.602916e-01 -2.341502e-01  4.850629e-01  0.717750
# ...             ...           ...           ...           ...       ...
# 20195 -6.772755e-07  1.054472e-06  5.339143e-07 -1.773716e-06 -0.000002
# 20196 -6.178858e-07  6.316946e-07  3.573773e-07 -1.450806e-06 -0.000003
# 20197 -5.548527e-07  2.866007e-07  2.107034e-07 -1.160592e-06 -0.000003
# 20198 -4.870830e-07  2.071877e-08  9.429965e-08 -9.018488e-07 -0.000003
# 20199 -4.181856e-07 -1.767912e-07  4.546968e-09 -6.756871e-07 -0.000003
#
#                   6             7         8             9
# ...
